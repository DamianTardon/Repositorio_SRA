# %%
# Definición de los valores de las resistencias
R1 = 100
R2 = 10000
R3 = 1000
R4 = 100000
a = 0.05

# Listas de valores de RL y Vin para variar
valores_RL = [0.000000000001, 1000, 2000, 5000, 10000]
valores_Vin = [-1, 0.5, 2]

# Bucle anidado para recorrer los valores de RL y Vin
for Vin in valores_Vin:
    for RL in valores_RL:
        # Cálculo de I_RL
        I_RL = Vin / (R3 + a * RL) * 1000 * 1000
        # Impresión de los resultados
        print(f"RL = {RL} Ω Vin = {Vin} V I_RL= {I_RL:.7f} mA")
# Out:
# RL = 1e-12 Ω Vin = -1 V I_RL= -1000.0000000 mA
# RL = 1000 Ω Vin = -1 V I_RL= -952.3809524 mA
# RL = 2000 Ω Vin = -1 V I_RL= -909.0909091 mA
# RL = 5000 Ω Vin = -1 V I_RL= -800.0000000 mA
# RL = 10000 Ω Vin = -1 V I_RL= -666.6666667 mA
# RL = 1e-12 Ω Vin = 0.5 V I_RL= 500.0000000 mA
# RL = 1000 Ω Vin = 0.5 V I_RL= 476.1904762 mA
# RL = 2000 Ω Vin = 0.5 V I_RL= 454.5454545 mA
# RL = 5000 Ω Vin = 0.5 V I_RL= 400.0000000 mA
# RL = 10000 Ω Vin = 0.5 V I_RL= 333.3333333 mA
# RL = 1e-12 Ω Vin = 2 V I_RL= 2000.0000000 mA
# RL = 1000 Ω Vin = 2 V I_RL= 1904.7619048 mA
# RL = 2000 Ω Vin = 2 V I_RL= 1818.1818182 mA
# RL = 5000 Ω Vin = 2 V I_RL= 1600.0000000 mA
# RL = 10000 Ω Vin = 2 V I_RL= 1333.3333333 mA
