# %%
Vsat_max = 10
Vsat_min = 0
R_3 = 2000
R_4 = 10000
Vref = 2

V_U_max = Vsat_max * (R_3 / (R_3 + R_4)) + Vref * (R_4 / (R_3 + R_4))
print(f"V_U_max = {V_U_max:.2f} V")

V_U_min = Vsat_min * (R_3 / (R_3 + R_4)) + Vref * (R_4 / (R_3 + R_4))
print(f"V_U_min = {V_U_min:.2f} V")
# Out:
# V_U_max = 3.33 V
# V_U_min = 1.67 V

# %%
V_U_min = (3.4081376+3.3201933) / 2
print(f"V_U_min = {V_U_min:.2f} V")

V_U_max = (6.1099491+6.1968083) / 2
print(f"V_U_max = {V_U_max:.2f} V")
# Out:
# V_U_min = 3.36 V
# V_U_max = 6.15 V
